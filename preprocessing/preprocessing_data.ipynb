# %% [markdown]
# # Preprocessing Kaggle Data

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Defining path to data

# %%
path_to_data = "C:/Users/Matheus/Desktop/Github/LEAGUE_RANKED_ANALYSIS/high_diamond_ranked_10min.csv"

# %% [markdown]
# ### Retrieving data

# %%
df = pd.read_csv(path_to_data, index_col=0)

# %%
df.head()
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4519157822         0               28                   2               1
# 4523371949         0               12                   1               0
# 4521474530         0               15                   0               0
# 4524384067         0               43                   1               0
# 4436033771         0               75                   4               0
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4519157822          9           6           11                  0
# 4523371949          5           5            5                  0
# 4521474530          7          11            4                  1
# 4524384067          4           5            5                  1
# 4436033771          6           6            6                  0
#
#             blueDragons  blueHeralds  ...  redTowersDestroyed  redTotalGold  \
# ...

# %% [markdown]
# ### Dataframe and variable analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9879 entries, 4519157822 to 4523772935
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   blueWins                      9879 non-null   int64
#  1   blueWardsPlaced               9879 non-null   int64
#  2   blueWardsDestroyed            9879 non-null   int64
#  3   blueFirstBlood                9879 non-null   int64
#  4   blueKills                     9879 non-null   int64
#  5   blueDeaths                    9879 non-null   int64
#  6   blueAssists                   9879 non-null   int64
#  7   blueEliteMonsters             9879 non-null   int64
#  8   blueDragons                   9879 non-null   int64
#  9   blueHeralds                   9879 non-null   int64
#  10  blueTowersDestroyed           9879 non-null   int64
#  11  blueTotalGold                 9879 non-null   int64
# ...

# %%
df.describe()
# Out:
#           blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# count  9879.000000      9879.000000         9879.000000     9879.000000
# mean      0.499038        22.288288            2.824881        0.504808
# std       0.500024        18.019177            2.174998        0.500002
# min       0.000000         5.000000            0.000000        0.000000
# 25%       0.000000        14.000000            1.000000        0.000000
# 50%       0.000000        16.000000            3.000000        1.000000
# 75%       1.000000        20.000000            4.000000        1.000000
# max       1.000000       250.000000           27.000000        1.000000
#
#          blueKills   blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# count  9879.000000  9879.000000  9879.000000        9879.000000  9879.000000
# mean      6.183925     6.137666     6.645106           0.549954     0.361980
# std       3.011028     2.933818     4.064520           0.625527     0.480597
# ...

# %% [markdown]
# ### Variables
# Looking at those 40 variables on our dataset, it is possible to notice that some of them correspond to correlated situations. As an example, we can take the Kills and Deaths of each side: red side kills will be the same as blue side deaths and vice versa.
#
# Separating some variables, we can move forward to prepare our dataframe for future analysis. Also, we are looking to answer some main questions with our data, so it is good to look into those repeated variables.
#
# #### Match Variables - 4
# - <font color=orange>blueWins</font> - match winner **(0 - red / 1 - blue)**
# - <font color=orange>blueFirstBlood</font> - match first blood **(0 - red / 1 - blue)**
# - <font color=blue>blueKills</font> - blue side kills **(red side deaths)**
# - <font color=red>redKills</font> - red side kills **(blue side deaths)**
#
# #### Map Control Variables - 12
# - <font color=blue>blueWardsPlaced</font>, <font color=blue>blueWardsDestroyed</font>
# - <font color=blue>blueEliteMonsters</font>
# - <font color=blue>blueTowersDestroyed</font>
# - <font color=blue>blueDragons</font>, <font color=blue>blueHeralds</font>
# - <font color=red>redWardsPlaced</font>, <font color=red>redWardsDestroyed</font>
# - <font color=red>redEliteMonsters</font>
# - <font color=red>redTowersDestroyed</font>
# - <font color=red>redDragons</font>, <font color=red>redHeralds</font>
#
# #### Side Advantage - 8
# - <font color=blue>blueAssists</font>
# - <font color=blue>blueTotalGold</font>
# - <font color=blue>blueTotalExperience</font>
# - <font color=blue>blueCSPerMin</font>
# - <font color=red>redAssists</font>
# - <font color=red>redTotalGold</font>
# - <font color=red>redTotalExperience</font>
# - <font color=red>redCSPerMin</font>
#
# It is important to notice that some variables were left behind due to their correspondence in other variables. We can use as an example the Advantage and Diff variables, that can be seen through the total variables difference.

# %% [markdown]
# ### Fixing dataframe

# %%
df_variables = ["blueWins", "blueFirstBlood", "blueKills", "redKills",
                "blueAssists", "redAssists",
                "blueWardsPlaced", "blueWardsDestroyed", "redWardsPlaced", "redWardsDestroyed",
                "blueEliteMonsters", "blueTowersDestroyed", "redEliteMonsters", "redTowersDestroyed",
                "blueDragons", "blueHeralds", "redDragons", "redHeralds",
                "blueTotalGold", "blueTotalExperience", "redTotalGold", "redTotalExperience", 
                "blueCSPerMin", "redCSPerMin"]

# %%
main_df = df[df_variables]

# %%
rename_variables = {"blueWins": "matchWinner", "blueFirstBlood": "matchFirstBlood"}
main_df = main_df.rename(columns=rename_variables)

# %%
main_df.head()
# Out:
#             matchWinner  matchFirstBlood  blueKills  redKills  blueAssists  \
# gameId
# 4519157822            0                1          9         6           11
# 4523371949            0                0          5         5            5
# 4521474530            0                0          7        11            4
# 4524384067            0                0          4         5            5
# 4436033771            0                0          6         6            6
#
#             redAssists  blueWardsPlaced  blueWardsDestroyed  redWardsPlaced  \
# gameId
# 4519157822           8               28                   2              15
# 4523371949           2               12                   1              12
# 4521474530          14               15                   0              15
# 4524384067          10               43                   1              15
# 4436033771           7               75                   4              17
#
# ...

# %% [markdown]
# ### Last changes on our dataset

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9879 entries, 4519157822 to 4523772935
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   matchWinner          9879 non-null   int64
#  1   matchFirstBlood      9879 non-null   int64
#  2   blueKills            9879 non-null   int64
#  3   redKills             9879 non-null   int64
#  4   blueAssists          9879 non-null   int64
#  5   redAssists           9879 non-null   int64
#  6   blueWardsPlaced      9879 non-null   int64
#  7   blueWardsDestroyed   9879 non-null   int64
#  8   redWardsPlaced       9879 non-null   int64
#  9   redWardsDestroyed    9879 non-null   int64
#  10  blueEliteMonsters    9879 non-null   int64
#  11  blueTowersDestroyed  9879 non-null   int64
#  12  redEliteMonsters     9879 non-null   int64
#  13  redTowersDestroyed   9879 non-null   int64
#  14  blueDragons          9879 non-null   int64
# ...

# %%
main_df.describe()
# Out:
#        matchWinner  matchFirstBlood    blueKills     redKills  blueAssists  \
# count  9879.000000      9879.000000  9879.000000  9879.000000  9879.000000
# mean      0.499038         0.504808     6.183925     6.137666     6.645106
# std       0.500024         0.500002     3.011028     2.933818     4.064520
# min       0.000000         0.000000     0.000000     0.000000     0.000000
# 25%       0.000000         0.000000     4.000000     4.000000     4.000000
# 50%       0.000000         1.000000     6.000000     6.000000     6.000000
# 75%       1.000000         1.000000     8.000000     8.000000     9.000000
# max       1.000000         1.000000    22.000000    22.000000    29.000000
#
#         redAssists  blueWardsPlaced  blueWardsDestroyed  redWardsPlaced  \
# count  9879.000000      9879.000000         9879.000000     9879.000000
# mean      6.662112        22.288288            2.824881       22.367952
# std       4.060612        18.019177            2.174998       18.457427
# ...

# %%
new_path_to_data = "C:/Users/Matheus/Desktop/Github/LEAGUE_RANKED_ANALYSIS/preprocessed_data.csv"

# %%
main_df.to_csv(new_path_to_data)
